# %% [markdown]
# <a href="https://colab.research.google.com/github/Susrinivas/Susrinivas_data606/blob/main/src/draft_proposal_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
import datetime

# %%
df = pd.read_csv('data1.csv')

# %%
df.shape
# Out:
# (229569, 8)

# %%
df.head(5)
# Out:
#        key  fare_amount          pickup_datetime  pickup_longitude  \
# 0  22:00.0        12.50  2014-02-19 07:22:00 UTC        -73.986430
# 1  36:22.0         4.00  2014-12-06 20:36:22 UTC        -73.979815
# 2  03:00.0         5.50  2014-02-19 16:03:00 UTC        -73.976075
# 3  46:34.0        22.54  2015-06-21 21:46:34 UTC        -74.010483
# 4  15:38.0        58.00  2015-01-11 03:15:38 UTC        -73.983330
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0        40.760465         -73.988990         40.737075                1
# 1        40.751902         -73.979446         40.755481                1
# 2        40.752422         -73.981082         40.759285                1
# 3        40.717667         -73.985771         40.660366                1
# 4        40.738720         -73.933197         40.847225                1

# %%
df.tail(5)
# Out:
#             key  fare_amount          pickup_datetime  pickup_longitude  \
# 229564  59:00.0          5.5  2014-02-08 20:59:00 UTC        -73.964947
# 229565  38:00.0         23.0  2014-07-31 13:38:00 UTC        -73.954010
# 229566  05:00.0          7.0  2014-09-13 17:05:00 UTC        -73.962580
# 229567  12:00.0         12.0  2014-01-10 19:12:00 UTC        -73.972328
# 229568  15:39.0         13.0  2015-03-31 13:15:39 UTC        -73.980576
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 229564        40.763735         -73.952747         40.766532                1
# 229565        40.784540         -73.990290         40.754177                5
# 229566        40.778222         -73.973827         40.764247                4
# 229567        40.745277         -73.987682         40.739162                1
# 229568        40.778145         -73.986252         40.752750                1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229569 entries, 0 to 229568
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   key                229569 non-null  object
#  1   fare_amount        229569 non-null  float64
#  2   pickup_datetime    229569 non-null  object
#  3   pickup_longitude   229569 non-null  float64
#  4   pickup_latitude    229569 non-null  float64
#  5   dropoff_longitude  229569 non-null  float64
#  6   dropoff_latitude   229569 non-null  float64
#  7   passenger_count    229569 non-null  int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 14.0+ MB

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# key                  0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# dtype: int64

# %%
df.drop(['key'], axis=1,inplace=True)

# %%
df
# Out:
#         fare_amount          pickup_datetime  pickup_longitude  \
# 0             12.50  2014-02-19 07:22:00 UTC        -73.986430
# 1              4.00  2014-12-06 20:36:22 UTC        -73.979815
# 2              5.50  2014-02-19 16:03:00 UTC        -73.976075
# 3             22.54  2015-06-21 21:46:34 UTC        -74.010483
# 4             58.00  2015-01-11 03:15:38 UTC        -73.983330
# ...             ...                      ...               ...
# 229564         5.50  2014-02-08 20:59:00 UTC        -73.964947
# 229565        23.00  2014-07-31 13:38:00 UTC        -73.954010
# 229566         7.00  2014-09-13 17:05:00 UTC        -73.962580
# 229567        12.00  2014-01-10 19:12:00 UTC        -73.972328
# 229568        13.00  2015-03-31 13:15:39 UTC        -73.980576
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0             40.760465         -73.988990         40.737075                1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229569 entries, 0 to 229568
# Data columns (total 7 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   fare_amount        229569 non-null  float64
#  1   pickup_datetime    229569 non-null  object
#  2   pickup_longitude   229569 non-null  float64
#  3   pickup_latitude    229569 non-null  float64
#  4   dropoff_longitude  229569 non-null  float64
#  5   dropoff_latitude   229569 non-null  float64
#  6   passenger_count    229569 non-null  int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 12.3+ MB

# %%
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])

# %%
df.info
# Out:
# <bound method DataFrame.info of         fare_amount           pickup_datetime  pickup_longitude  \
# 0             12.50 2014-02-19 07:22:00+00:00        -73.986430
# 1              4.00 2014-12-06 20:36:22+00:00        -73.979815
# 2              5.50 2014-02-19 16:03:00+00:00        -73.976075
# 3             22.54 2015-06-21 21:46:34+00:00        -74.010483
# 4             58.00 2015-01-11 03:15:38+00:00        -73.983330
# ...             ...                       ...               ...
# 229564         5.50 2014-02-08 20:59:00+00:00        -73.964947
# 229565        23.00 2014-07-31 13:38:00+00:00        -73.954010
# 229566         7.00 2014-09-13 17:05:00+00:00        -73.962580
# 229567        12.00 2014-01-10 19:12:00+00:00        -73.972328
# 229568        13.00 2015-03-31 13:15:39+00:00        -73.980576
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0             40.760465         -73.988990         40.737075                1
# ...

# %% [markdown]
# EDA

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(14,4))
plt.hist(df['fare_amount'],1000,facecolor="blue")
plt.xlabel('fare amount')
plt.ylabel('count')
plt.title('fare amount')
plt.xlim(0,100)
# Out:
# (0.0, 100.0)

# %%
df['passenger_count'].value_counts().plot.bar()
plt.title('Histogram of Passenger Count')
plt.xlabel('Passenger Count')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df['passenger_count'].value_counts()
# Out:
# 1    161669
# 2     32379
# 5     12813
# 3      9641
# 6      8443
# 4      4586
# 0        37
# 9         1
# Name: passenger_count, dtype: int64

# %% [markdown]
# What are the factors affect the fare amount ?
#
# 1. Distance
# 2. Time travelled
# 3. pickup and dropoff locations
# 4. No of passengers
# 5. Traffic

# %%
import folium

# %%
nyc=folium.Map(location=[40.730610,-73.935242],zomm_start=12,)

# %%
nyc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
for i in df.index[:100]:
  folium.CircleMarker(location=[df['pickup_latitude'][i],df['pickup_longitude'][i]],color='blue').add_to(nyc)

# %%
nyc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
for i in df.index[:100]:
  folium.CircleMarker(location=[df['dropoff_latitude'][i],df['dropoff_longitude'][i]],color='green').add_to(nyc)

# %%
nyc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ####Feature Engineering

# %%
df['year']=df.pickup_datetime.dt.year
df['month']=df.pickup_datetime.dt.month
df['day']=df.pickup_datetime.dt.day
df['weekday']=df.pickup_datetime.dt.weekday
df['hour']=df.pickup_datetime.dt.hour

# %%
df.head()
# Out:
#    fare_amount           pickup_datetime  pickup_longitude  pickup_latitude  \
# 0        12.50 2014-02-19 07:22:00+00:00        -73.986430        40.760465
# 1         4.00 2014-12-06 20:36:22+00:00        -73.979815        40.751902
# 2         5.50 2014-02-19 16:03:00+00:00        -73.976075        40.752422
# 3        22.54 2015-06-21 21:46:34+00:00        -74.010483        40.717667
# 4        58.00 2015-01-11 03:15:38+00:00        -73.983330        40.738720
#
#    dropoff_longitude  dropoff_latitude  passenger_count  year  month  day  \
# 0         -73.988990         40.737075                1  2014      2   19
# 1         -73.979446         40.755481                1  2014     12    6
# 2         -73.981082         40.759285                1  2014      2   19
# 3         -73.985771         40.660366                1  2015      6   21
# 4         -73.933197         40.847225                1  2015      1   11
#
#    weekday  hour
# 0        2     7
# 1        5    20
# ...

# %%
df.groupby("weekday")["fare_amount"].mean().plot()
plt.title('fare price changes in a week')
# Out:
# Text(0.5, 1.0, 'fare price changes in a week')

# %% [markdown]
# Average fare hits the lowest on Friday and hikes up on Saturday.

# %%
df.groupby("hour")["fare_amount"].mean().plot()
plt.title('fare price changes in a day')
# Out:
# Text(0.5, 1.0, 'fare price changes in a day')

# %% [markdown]
# Taxi fare has 3 peaks in a day, 3-6, 13-16 and 23-2. Fare tends to go up in after-midnight which could due to surcharge or the fact that public transportations are closed so commuters have to hire taxi instead even for long trip.
#
# Now we use haversine formual to find distance betwee two points

# %% [markdown]
# The haversine distance is the angular distance between two points on
#
# 1.   List item
# 2.   List item
#
# the surface of a sphere.
#
# As the Earth is spherical, the haversine formula provides a good approximation of the distance between two points on the earths surface with less that 1% error on average

# %%
import numpy as np
from math import radians, cos, sin, asin, sqrt

def haversine_np(lon1, lat1, lon2, lat2):
   # convert decimal degrees to radians 
   lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])

      # haversine formula 
   dlon = lon2 - lon1 
   dlat = lat2 - lat1 
   a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2
   c = 2 * np.arcsin(np.sqrt(a)) 
   r = 6367 # Radius of earth in kilometers.
   return c * r

# %%
df['distance'] = haversine_np(df['pickup_longitude'], df['pickup_latitude'], df['dropoff_longitude'], df['dropoff_latitude'])

# %%
df.head()
# Out:
#    fare_amount           pickup_datetime  pickup_longitude  pickup_latitude  \
# 0        12.50 2014-02-19 07:22:00+00:00        -73.986430        40.760465
# 1         4.00 2014-12-06 20:36:22+00:00        -73.979815        40.751902
# 2         5.50 2014-02-19 16:03:00+00:00        -73.976075        40.752422
# 3        22.54 2015-06-21 21:46:34+00:00        -74.010483        40.717667
# 4        58.00 2015-01-11 03:15:38+00:00        -73.983330        40.738720
#
#    dropoff_longitude  dropoff_latitude  passenger_count  year  month  day  \
# 0         -73.988990         40.737075                1  2014      2   19
# 1         -73.979446         40.755481                1  2014     12    6
# 2         -73.981082         40.759285                1  2014      2   19
# 3         -73.985771         40.660366                1  2015      6   21
# 4         -73.933197         40.847225                1  2015      1   11
#
#    weekday  hour   distance
# 0        2     7   2.608136
# ...

# %%
plt.scatter(df["distance"], df["fare_amount"])

# %% [markdown]
# It seems that distance and fare have week correlation but we see some of the travel distance are unfairly long, they might be outside of NYC already.

# %%
df.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  229569.000000     229569.000000    229569.000000      229569.000000
# mean       12.943437        -72.598451        39.992290         -72.592162
# std        11.351594          9.996080         5.507897          10.015504
# min       -20.000000       -108.202955       -19.721222        -108.202955
# 25%         6.500000        -73.992020        40.734930         -73.991322
# 50%         9.500000        -73.981760        40.752677         -73.979774
# 75%        14.500000        -73.966812        40.767314         -73.962463
# max       495.000000          0.000000        47.267397           0.000000
#
#        dropoff_latitude  passenger_count           year          month  \
# count     229569.000000    229569.000000  229569.000000  229569.000000
# mean          39.989824         1.691979    2014.318771       5.490288
# std            5.518715         1.350141       0.466001       3.284405
# ...

# %% [markdown]
# There are three parts of abnormal data that we need to drop off before proceeding the analysis
# 1. pickup coordinates are not within NYC(-73.9, 40.7)
# 2. travel distance greater than 100 km
# 3. zero or negative fare amount ( > 2.5 )

# %%
df_trim=df.loc[df['pickup_latitude'].between(40,42)]
df_trim=df.loc[df['pickup_longitude'].between(-75,-72)]
df_trim=df.loc[df['dropoff_latitude'].between(40,42)]
df_trim=df.loc[df['dropoff_longitude'].between(-75,-72)]

# %%
df_trim = df[df["fare_amount"] > 2.5]


df_trim = df_trim[(df_trim["distance"] < 100) & (df_trim["distance"] > 0)]

# %%
df_trim.head()
# Out:
#    fare_amount           pickup_datetime  pickup_longitude  pickup_latitude  \
# 0        12.50 2014-02-19 07:22:00+00:00        -73.986430        40.760465
# 1         4.00 2014-12-06 20:36:22+00:00        -73.979815        40.751902
# 2         5.50 2014-02-19 16:03:00+00:00        -73.976075        40.752422
# 3        22.54 2015-06-21 21:46:34+00:00        -74.010483        40.717667
# 4        58.00 2015-01-11 03:15:38+00:00        -73.983330        40.738720
#
#    dropoff_longitude  dropoff_latitude  passenger_count  year  month  day  \
# 0         -73.988990         40.737075                1  2014      2   19
# 1         -73.979446         40.755481                1  2014     12    6
# 2         -73.981082         40.759285                1  2014      2   19
# 3         -73.985771         40.660366                1  2015      6   21
# 4         -73.933197         40.847225                1  2015      1   11
#
#    weekday  hour   distance
# 0        2     7   2.608136
# ...

# %%
df_trim.shape[0]/df.shape[0]
# Out:
# 0.9709499104844295

# %% [markdown]
# After trimmed out all abnormal data, we still have around 97% of data left

# %%
sc = plt.scatter(df_trim["pickup_longitude"], df_trim["pickup_latitude"], c = df_trim["fare_amount"], cmap = "summer")
plt.colorbar(sc)

# %% [markdown]
# Unfortunately, by plotting out pickup coordinates with color representing fare amount we're still not able to see clear boundries seperating areas with different level of taxi fare.

# %%
plt.scatter(df_trim["distance"], df_trim["fare_amount"])
plt.xlabel('distance')
plt.ylabel('fare_amount')
plt.title('scatter plot between distance and fare amount')
# Out:
# Text(0.5, 1.0, 'scatter plot between distance and fare amount')

# %% [markdown]
# After clearing abnormal data, the correlationship between travel distance and fare becomes more clear. We print out correlation coefficient of fare_amount and other variables at below, it shows 0.86 for distance which is very high. Other medium-highly correlated variables are pickup_longitude and dropoff_longitude, can be explained that traveling from/to the east side of NYC would have higher taxi cost.

# %%
plt.scatter(df_trim["pickup_longitude"], df_trim["fare_amount"])
plt.xlabel('pickup_longitude')
plt.ylabel('fare_amount')
# Out:
# Text(0, 0.5, 'fare_amount')

# %%
df_trim.corr()["fare_amount"].sort_values(ascending = False)
# Out:
# <ipython-input-41-763a85986c81>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_trim.corr()["fare_amount"].sort_values(ascending = False)
# fare_amount          1.000000
# distance             0.896694
# pickup_longitude     0.459607
# dropoff_longitude    0.322047
# month                0.021694
# passenger_count      0.011762
# year                 0.004400
# day                  0.003358
# weekday             -0.006200
# hour                -0.017280
# dropoff_latitude    -0.170067
# pickup_latitude     -0.246203
# Name: fare_amount, dtype: float64

# %%
plt.scatter(df_trim["pickup_longitude"], df_trim["fare_amount"])
plt.xlabel('pickup_longitude')
plt.ylabel('fare_amount')
# Out:
# Text(0, 0.5, 'fare_amount')

# %%
import seaborn as sns

# %%
 df['distance'].describe()
# Out:
# count    229569.000000
# mean         33.802732
# std         512.319700
# min           0.000000
# 25%           1.223993
# 50%           2.124236
# 75%           3.941647
# max        8694.219498
# Name: distance, dtype: float64

# %%
pd.concat([d.reset_index(drop=True) for d in [X_test['fare_amount'], y_test['fare_amount']]], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-02e9b75ad230> in <cell line: 1>()
# ----> 1 pd.concat([d.reset_index(drop=True) for d in [X_test['fare_amount'], y_test['fare_amount']]], axis=1)
#
# NameError: name 'X_test' is not defined

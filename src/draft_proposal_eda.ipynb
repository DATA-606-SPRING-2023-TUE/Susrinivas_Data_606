# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
crime_data = pd.read_csv("Crime_data.csv")
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
crime_data
# Out:
#                 X          Y   RowID           CrimeDateTime CrimeCode  \
# 0      -76.633897  39.307399       1  2023/01/28 15:31:00+00        5A
# 1      -76.536391  39.287928       2  2023/01/28 15:20:00+00        6F
# 2        0.000000   0.000000       3  2023/01/28 20:30:00+00        6D
# 3      -76.613381  39.306251       4  2023/01/28 00:00:00+00        4E
# 4      -76.687437  39.370173       5  2023/01/28 13:00:00+00        6F
# ...           ...        ...     ...                     ...       ...
# 479402 -76.623461  39.315686  479403  2012/05/23 05:00:00+00        6D
# 479403 -76.534508  39.284084  479404  2012/06/17 02:20:00+00        4E
# 479404 -76.543101  39.364114  479405  2012/06/17 03:45:00+00        4E
# 479405 -76.551031  39.286110  479406  2012/06/17 22:30:00+00        7C
# 479406 -76.609605  39.258510  479407  2012/06/17 21:30:00+00        6C
#
#                       Location        Description Inside_Outside Weapon Post  \
# ...

# %%
crime_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479407 entries, 0 to 479406
# Data columns (total 23 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   X                478843 non-null  float64
#  1   Y                478843 non-null  float64
#  2   RowID            479407 non-null  int64
#  3   CrimeDateTime    479407 non-null  object
#  4   CrimeCode        479407 non-null  object
#  5   Location         477050 non-null  object
#  6   Description      479407 non-null  object
#  7   Inside_Outside   399054 non-null  object
#  8   Weapon           110353 non-null  object
#  9   Post             466968 non-null  object
#  10  Gender           399178 non-null  object
#  11  Age              382229 non-null  float64
#  12  Race             469411 non-null  object
#  13  Ethnicity        20039 non-null   object
#  14  District         467105 non-null  object
#  15  Neighborhood     466965 non-null  object
# ...

# %%
crime_data.describe()
# Out:
#                    X              Y          RowID            Age  \
# count  478843.000000  478843.000000  479407.000000  382229.000000
# mean      -74.201476      38.067270  239704.000000      37.629269
# std        13.389975       6.869430  138393.024588      39.168842
# min       -76.711194       0.000000       1.000000   -7979.000000
# 25%       -76.648260      39.286925  119852.500000      26.000000
# 50%       -76.612895      39.301574  239704.000000      34.000000
# 75%       -76.582987      39.326047  359555.500000      49.000000
# max         0.000000      39.371977  479407.000000    8251.000000
#
#             Latitude      Longitude  Total_Incidents  Shape
# count  478842.000000  478842.000000         479406.0    0.0
# mean       38.067267     -74.201471              1.0    NaN
# std         6.869437      13.389989              0.0    NaN
# min         0.000000     -76.711194              1.0    NaN
# 25%        39.286925     -76.648260              1.0    NaN
# ...

# %%
crime_data.count()
# Out:
# X                  478843
# Y                  478843
# RowID              479407
# CrimeDateTime      479407
# CrimeCode          479407
# Location           477050
# Description        479407
# Inside_Outside     399054
# Weapon             110353
# Post               466968
# Gender             399178
# Age                382229
# Race               469411
# Ethnicity           20039
# District           467105
# Neighborhood       466965
# Latitude           478842
# Longitude          478842
# GeoLocation        479406
# Premise            398733
# VRIName             56293
# Total_Incidents    479406
# Shape                   0
# dtype: int64

# %%
# checking count of null values in the data
crime_data.isnull().sum()
# Out:
# X                     564
# Y                     564
# RowID                   0
# CrimeDateTime           0
# CrimeCode               0
# Location             2357
# Description             0
# Inside_Outside      80353
# Weapon             369054
# Post                12439
# Gender              80229
# Age                 97178
# Race                 9996
# Ethnicity          459368
# District            12302
# Neighborhood        12442
# Latitude              565
# Longitude             565
# GeoLocation             1
# Premise             80674
# VRIName            423114
# Total_Incidents         1
# Shape              479407
# dtype: int64

# %%
crime_data.shape
# Out:
# (479407, 23)

# %%
duplicate_rows_df = crime_data[crime_data.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 23)

# %%
# checking data types
crime_data.dtypes
# Out:
# X                  float64
# Y                  float64
# RowID                int64
# CrimeDateTime       object
# CrimeCode           object
# Location            object
# Description         object
# Inside_Outside      object
# Weapon              object
# Post                object
# Gender              object
# Age                float64
# Race                object
# Ethnicity           object
# District            object
# Neighborhood        object
# Latitude           float64
# Longitude          float64
# GeoLocation         object
# Premise             object
# VRIName             object
# Total_Incidents    float64
# Shape              float64
# dtype: object

# %% [markdown]
# Top crimes in Baltimore

# %%
crime_data['Neighborhood'].value_counts().head(15).plot.bar( figsize = (20, 10))
plt.title('Top Crimes in baltimore', fontweight = 30, fontsize = 20)
plt.show()

# %% [markdown]
# Types of crimes in Baltimore

# %%
crime_data['Description'].value_counts()
# Out:
# LARCENY                 107425
# COMMON ASSAULT           85926
# BURGLARY                 64892
# LARCENY FROM AUTO        61275
# AGG. ASSAULT             55059
# AUTO THEFT               41288
# ROBBERY                  39273
# SHOOTING                  6042
# ROBBERY - COMMERCIAL      5312
# ROBBERY - CARJACKING      4468
# HOMICIDE                  3252
# RAPE                      3157
# ARSON                     2037
# LARCE                        1
# Name: Description, dtype: int64

# %%
crime_data['Weapon'].value_counts()
# Out:
# FIREARM                           44109
# OTHER                             27246
# KNIFE                             16552
# PERSONAL_WEAPONS                  10028
# HANDS                              5922
# FIRE                               1906
# HANDGUN                            1793
# KNIFE_CUTTING_INSTRUMENT           1165
# BLUNT_OBJECT                        808
# UNKNOWN                             349
# MOTOR_VEHICLE_VESSEL                173
# AUTOMATIC_HANDGUN                    81
# ASPHYXIATION                         41
# SHOTGUN                              38
# OTHER_FIREARM                        38
# FIRE_INCENDIARY_DEVICE               32
# RIFLE                                26
# AUTOMATIC_FIREARM                    25
# POISON                               11
# AUTOMATIC_RIFLE                       4
# EXPLOSIVES                            4
# DRUGS_NARCOTICS_SLEEPING_PILLS        1
# AUTOMATIC_OTHER_FIREARM               1
# Name: Weapon, dtype: int64
